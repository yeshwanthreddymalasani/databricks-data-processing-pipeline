# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

spark = SparkSession.builder.appName("Ecommerce Data Processing").getOrCreate()
try:
df = spark.read.csv("/Workspace/Users/yeshwanthreddy0974@gmail.com/databricks-data-processing-pipeline/Datasets/ecommerce_data.csv", header=True, inferSchema=True)
except exception as e:
    raise error
df_clean = df.dropna()

df_transformed = df_clean.withColumn(
    "total_price",
    col("price") * col("quantity")
)

df_transformed.show()
dbutils.notebooks.exit("notebook executed successfully")

# %%
df.show()
